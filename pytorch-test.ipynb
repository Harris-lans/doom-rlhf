# %%
import os
from stable_baselines3.common.callbacks import BaseCallback

# Creating callback for PPO algorithm
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_frequency, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_frequency = check_frequency
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_frequency == 0:
            model_path = os.path.join(self.save_path, f"best_model_{self.n_calls}")
            self.model.save(model_path)

# %%
CHECKPOINT_DIR = './models/basic'
LOG_DIR = './logs/basic'

# %%
from envs.doom_env import DoomEnv
from stable_baselines3.common import env_checker

# Initializing environment
env = DoomEnv('vizdoom/scenarios/basic.cfg', True)

# Checking environment compatability
env_checker.check_env(env)

# %%
from stable_baselines3 import PPO

callback = TrainAndLoggingCallback(10000, CHECKPOINT_DIR)
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# Training model using PPO algorithm
model.learn(total_timesteps=70000, callback=callback)
# Out:
# Logging to ./logs/basic\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.8     |
# |    ep_rew_mean     | -92.6    |
# | time/              |          |
# |    fps             | 32       |
# |    iterations      | 1        |
# |    time_elapsed    | 63       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.4        |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 2           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009397702 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 3.82e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 698         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 2.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | -39.4       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 3           |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013875363 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0548      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1e+03       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 2.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | -31.2       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 4           |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014586063 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.23e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00221     |
# |    value_loss           | 3.13e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.7       |
# |    ep_rew_mean          | -3.24      |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 5          |
# |    time_elapsed         | 281        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.07108246 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.471      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.33e+03   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.00825    |
# |    value_loss           | 3.67e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.2        |
# |    ep_rew_mean          | 11.1        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 6           |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024253972 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.8e+03     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 3.59e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.7        |
# |    ep_rew_mean          | 1.13        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 7           |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.026695646 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00614     |
# |    value_loss           | 3.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.2        |
# |    ep_rew_mean          | -7.97       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 8           |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014057262 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.69e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000542   |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.4       |
# |    ep_rew_mean          | 20.1       |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 9          |
# |    time_elapsed         | 497        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.05536469 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.874     |
# |    explained_variance   | 0.585      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.75e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.00874    |
# |    value_loss           | 3.1e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.5        |
# |    ep_rew_mean          | 61.4       |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 10         |
# |    time_elapsed         | 552        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01712184 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.818     |
# |    explained_variance   | 0.704      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.5e+03    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -8.74e-05  |
# |    value_loss           | 2.53e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | 40.3       |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 11         |
# |    time_elapsed         | 607        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.04742714 |
# |    clip_fraction        | 0.471      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.873     |
# |    explained_variance   | 0.361      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.02e+03   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.0174     |
# |    value_loss           | 1.61e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 57.5        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 12          |
# |    time_elapsed         | 665         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.049945757 |
# |    clip_fraction        | 0.495       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.42e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 2.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.1       |
# |    ep_rew_mean          | 44         |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 13         |
# |    time_elapsed         | 716        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.10794096 |
# |    clip_fraction        | 0.513      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.748     |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 347        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0802     |
# |    value_loss           | 776        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.25        |
# |    ep_rew_mean          | 62.9        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 14          |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.043833934 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 586         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00803     |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.76       |
# |    ep_rew_mean          | 74.4       |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 15         |
# |    time_elapsed         | 833        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03974042 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.679     |
# |    explained_variance   | 0.69       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 351        |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00198   |
# |    value_loss           | 888        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.95        |
# |    ep_rew_mean          | 74.2        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 16          |
# |    time_elapsed         | 888         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.061052132 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 195         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0166      |
# |    value_loss           | 449         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.02       |
# |    ep_rew_mean          | 82.8       |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 17         |
# |    time_elapsed         | 949        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.07533221 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.539     |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 134        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0137     |
# |    value_loss           | 269        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.59       |
# |    ep_rew_mean          | 80         |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 18         |
# |    time_elapsed         | 1004       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.04907439 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.454     |
# |    explained_variance   | 0.669      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 109        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00696    |
# |    value_loss           | 171        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.43       |
# |    ep_rew_mean          | 84.8       |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 19         |
# |    time_elapsed         | 1063       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.06191613 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.396     |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 82.4       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.00904    |
# |    value_loss           | 164        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.37       |
# |    ep_rew_mean          | 85.1       |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 20         |
# |    time_elapsed         | 1123       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.12173667 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.314     |
# |    explained_variance   | 0.541      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 97.2       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0302     |
# |    value_loss           | 143        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.16        |
# |    ep_rew_mean          | 86.3        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 21          |
# |    time_elapsed         | 1184        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023968581 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.281      |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 37.1        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 80.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.91        |
# |    ep_rew_mean          | 87          |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 22          |
# |    time_elapsed         | 1249        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.040232137 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.48        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0326      |
# |    value_loss           | 32          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.54        |
# |    ep_rew_mean          | 84.3        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 23          |
# |    time_elapsed         | 1305        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022339877 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.228      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20.1        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0443      |
# |    value_loss           | 44.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.43       |
# |    ep_rew_mean          | 84.2       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 24         |
# |    time_elapsed         | 1369       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03730809 |
# |    clip_fraction        | 0.0708     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.187     |
# |    explained_variance   | 0.765      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 22.8       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.00561    |
# |    value_loss           | 42.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.16        |
# |    ep_rew_mean          | 86.1        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 25          |
# |    time_elapsed         | 1425        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023169756 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 126         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0154      |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.72        |
# |    ep_rew_mean          | 87.8        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 26          |
# |    time_elapsed         | 1486        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.039875876 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.166      |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 30.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00325    |
# |    value_loss           | 146         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.14       |
# |    ep_rew_mean          | 86         |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 27         |
# |    time_elapsed         | 1544       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01219877 |
# |    clip_fraction        | 0.0924     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.158     |
# |    explained_variance   | 0.81       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 22.4       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0495     |
# |    value_loss           | 22.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.43        |
# |    ep_rew_mean          | 84.8        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 28          |
# |    time_elapsed         | 1602        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025985235 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.14       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0133      |
# |    value_loss           | 30.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.1        |
# |    ep_rew_mean          | 86         |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 29         |
# |    time_elapsed         | 1681       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.03621249 |
# |    clip_fraction        | 0.0988     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.13      |
# |    explained_variance   | 0.724      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 19.5       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0148     |
# |    value_loss           | 38.8       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 4.45     |
# |    ep_rew_mean          | 84.2     |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 30       |
# |    time_elapsed         | 1739     |
# |    total_timesteps      | 61440    |
# | train/                  |          |
# |    approx_kl            | 0.039747 |
# |    clip_fraction        | 0.1      |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.114   |
# |    explained_variance   | 0.697    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 21.6     |
# |    n_updates            | 290      |
# |    policy_gradient_loss | 0.0441   |
# |    value_loss           | 56.5     |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.66       |
# |    ep_rew_mean          | 88.1       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 31         |
# |    time_elapsed         | 1801       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.04804969 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.12      |
# |    explained_variance   | 0.673      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 27.2       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.035      |
# |    value_loss           | 55.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.83        |
# |    ep_rew_mean          | 87.5        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 32          |
# |    time_elapsed         | 1860        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.021509476 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.103      |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.96        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00785     |
# |    value_loss           | 20.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.85       |
# |    ep_rew_mean          | 87.4       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 33         |
# |    time_elapsed         | 1924       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.05644371 |
# |    clip_fraction        | 0.0942     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.127     |
# |    explained_variance   | 0.826      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 34.9       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 72.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.19        |
# |    ep_rew_mean          | 85.7        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 34          |
# |    time_elapsed         | 1982        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.019889917 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.8        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0246      |
# |    value_loss           | 15.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.16        |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 35          |
# |    time_elapsed         | 2045        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.049326576 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0958     |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 28.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0156      |
# |    value_loss           | 45.6        |
# -----------------------------------------

# %%
env.close()
